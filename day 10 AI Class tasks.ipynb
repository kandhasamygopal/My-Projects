# %%
class Cars():
  def __init__(self,brand,model):

   self.brand = brand

   self.model = model

c1=Cars("Suzuki","2015")
c2=Cars("Maruthi","2016")

print(f"{c1.brand} and is a {c1.model} Model.")
print(f"{c2.brand} and is a {c2.model} Model.")
# Out:
# Suzuki and is a 2015 Model.
# Maruthi and is a 2016 Model.

# %%
class Person():
  spicies= "Human"
  def __init__(self ,name ,age) -> None:
    self.name = name
    self.age = age

person1=Person("Gopal",30)
person2=Person("jino",26)
print(f"{person1.name} is a {person1.spicies} is age {person1.age}your old")
print(f"{person2.name} is a {person2.spicies} is age {person2.age}your old")
# Out:
# Gopal is a Human is age 30your old
# jino is a Human is age 26your old

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-22-6786068ec7f8> in <cell line: 1>()
# ----> 1 c1=Cars("Suzuki","maruthi")
#       2 c2=Cars(2015,2016)
#       3 print(f"{c1.brand} and is a {c2.model} Model.")
#
# <ipython-input-20-746c7e2d251e> in __init__(self, brand, model)
#       6    self.model = model
#       7
# ----> 8    c1=Cars("Suzuki","maruthi")
#       9    c2=Cars(2015,2016)
#      10    print(f"{c1.brand} and is a {c2.model} Model.")
#
# <ipython-input-20-746c7e2d251e> in __init__(self, brand, model)
#       6    self.model = model
#       7
# ----> 8    c1=Cars("Suzuki","maruthi")
#       9    c2=Cars(2015,2016)
#      10    print(f"{c1.brand} and is a {c2.model} Model.")
#
# <ipython-input-20-746c7e2d251e> in __init__(self, brand, model)
#       6    self.model = model
#       7
# ----> 8    c1=Cars("Suzuki","maruthi")
# ...
